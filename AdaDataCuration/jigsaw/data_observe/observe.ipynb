# %%
from tool_server.utils.utils import *
input_data_source = "/mnt/petrelfs/songmingyang/songmingyang/data/mm/imgs/coco/train2017"

# %%
image_list = os.listdir(input_data_source)

idx = 5
image_file = image_list[idx]
image_path = os.path.join(input_data_source, image_file)

display(Image.open(image_path))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x425>
# notebook controller is DISPOSED.
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

# %%
image_list[0]
# Out:
# '000000113333.jpg'
# notebook controller is DISPOSED.
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

# %%
# Out:
# notebook controller is DISPOSED.
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

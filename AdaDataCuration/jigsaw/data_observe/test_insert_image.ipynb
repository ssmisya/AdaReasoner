# %%
from tool_server.utils.utils import * 
from tool_server.tool_workers.tool_manager.base_manager import ToolManager
# Out:
# 2025-09-10 15:04:55 | INFO | base_offline_worker | Initialized offline worker: AStarWithPixelCoordinate
# 2025-09-10 15:04:55 | INFO | base_offline_worker | Initialized offline worker: Draw2DPath
# 2025-09-10 15:04:55 | INFO | base_offline_worker | Initialized offline worker: TurnCoordinateIntoTextMap
# 2025-09-10 15:04:55 | INFO | base_offline_worker | Initialized offline worker: DetectBlackArea
# 2025-09-10 15:04:55 | INFO | base_offline_worker | Initialized offline worker: InsertImage

# %%
tool_manager = ToolManager()
# Out:
# 2025-09-10 15:05:05 | INFO | tool_manager | Offline Tools: ['AStarWithPixelCoordinate', 'Draw2DPath', 'TurnCoordinateIntoTextMap', 'DetectBlackArea', 'InsertImage']
# 2025-09-10 15:05:05 | INFO | tool_manager | controller_addr is None, using default from controller_addr_location
# 2025-09-10 15:05:05 | INFO | tool_manager | Online Tools: ['Point']
# 2025-09-10 15:05:05 | INFO | stdout | available_tools ['Point', 'AStarWithPixelCoordinate', 'Draw2DPath', 'TurnCoordinateIntoTextMap', 'DetectBlackArea', 'InsertImage']
# 2025-09-10 15:05:05 | INFO | tool_manager | Not all required online tools are prepared successfully, missing: ['GroundingDINO', 'OCR', 'SegmentRegionAroundPoint', 'Crop', 'DrawLine', 'DrawShape', 'HighlightBox', 'MaskBox', 'GetSubplotInfo', 'GetBarInfo']
# 2025-09-10 15:05:05 | INFO | tool_manager | ToolManager is initialized.

# %%
params = {
        "base_image": base_image,
        "image_to_insert": insert_image_path,
        "coordinates": coordinates,
    }

# %%
tool_manager.call_tool

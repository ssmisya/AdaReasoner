# %%
from tool_server.utils.utils import *
import random

# %%
jigsaw_sft_data_file = "/mnt/petrelfs/share_data/songmingyang/data/vl_reasoning/tool_dataset/jigsaw/jigsaw_metadata_v1/splits/sft/gemini_enhanced/sft_data/jigsaw_sft_v1.json"
original_sft_data = load_json_file(jigsaw_sft_data_file)

# %%
len(original_sft_data)
# Out:
# 1125

# %%
random.shuffle(original_sft_data)
sft_300_data = original_sft_data[:300]
random.shuffle(original_sft_data)
sft_600_data = original_sft_data[:600]
random.shuffle(original_sft_data)
sft_900_data = original_sft_data[:900]

sft_300_file = jigsaw_sft_data_file.replace(".json", "_300.json")
sft_600_file = jigsaw_sft_data_file.replace(".json", "_600.json")
sft_900_file = jigsaw_sft_data_file.replace(".json", "_900.json")

write_json_file(sft_300_data, sft_300_file)
write_json_file(sft_600_data, sft_600_file)
write_json_file(sft_900_data, sft_900_file)

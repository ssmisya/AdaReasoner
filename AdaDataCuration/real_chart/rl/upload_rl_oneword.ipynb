# %%
from datasets import Features, Value, Sequence,load_dataset
from tool_server.utils.utils import *
from tool_server.utils.prompts import tool_planning_model_prompt_one_tool_call
from tqdm import tqdm
import json, os
import random
random.seed(42)
from PIL import Image
setup_proxy()

# %%
refined_data = "datasets/tool_rlset_v1_refined"
dataset = load_dataset(refined_data)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]

# %%
# Define the dataset name for HuggingFace
dataset_name = "tool_rlset_v1.1"

# Push to the Hugging Face Hub
dataset.push_to_hub(dataset_name, token="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")  # Replace with your actual token
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/20 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/hitsmy/tool_rlset_v1.1/commit/9562089a240ddeee9ea4ca6d31e4be46881e3976', commit_message='Upload dataset', commit_description='', oid='9562089a240ddeee9ea4ca6d31e4be46881e3976', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/hitsmy/tool_rlset_v1.1', endpoint='https://huggingface.co', repo_type='dataset', repo_id='hitsmy/tool_rlset_v1.1'), pr_revision=None, pr_num=None)

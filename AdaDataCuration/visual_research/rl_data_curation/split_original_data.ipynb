# %%
from datasets import load_dataset
from tool_server.utils.utils import *
setup_proxy()
import random
random.seed(42)

# %%
input_data = "/mnt/petrelfs/songmingyang/code/reasoning/tool_util_code/visual_research/vs_data/visualcot_tit_with_bbox.json"
input_data = load_json_file(input_data)
len(input_data)
# Out:
# 6990

# %%
random.shuffle(input_data)
rl_data = input_data[:3000]
rest_data = input_data[3000:]

# %%
rl_data_output_path = "/mnt/petrelfs/songmingyang/code/reasoning/tool_util_code/visual_research/vs_data/raw_data/rl_data.json"
rest_data_outpath =  "/mnt/petrelfs/songmingyang/code/reasoning/tool_util_code/visual_research/vs_data/raw_data/rest_data.json"
write_json_file(rl_data,rl_data_output_path)
write_json_file(rest_data,rest_data_outpath)

# %%
from datasets import load_dataset
load_dataset("ThinkMorph/Visual_Search",split="train")
# Out:
# Generating train split:   0%|          | 0/6990 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/anaconda3/envs/vllm2/lib/python3.10/site-packages/datasets/builder.py:1855, in ArrowBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, job_id)
#    1854 _time = time.time()
# -> 1855 for _, table in generator:
#    1856     if max_shard_size is not None and writer._num_bytes > max_shard_size:
#
# File ~/anaconda3/envs/vllm2/lib/python3.10/site-packages/datasets/packaged_modules/parquet/parquet.py:93, in Parquet._generate_tables(self, files)
#      92 try:
# ---> 93     for batch_idx, record_batch in enumerate(
#      94         parquet_fragment.to_batches(
#      95             batch_size=batch_size,
#      96             columns=self.config.columns,
#      97             filter=filter_expr,
# ...

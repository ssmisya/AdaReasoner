# %%
from tool_server.utils.utils import *
from datasets import load_dataset

# %%
blink_path = "/mnt/petrelfs/songmingyang/songmingyang/data/vl_reasoning/tool_dataset/BLINK"
blink_dataset = load_dataset(blink_path,"Jigsaw")
# Out:
# ...
# Generating test split:   0%|          | 0/150 [00:00<?, ? examples/s]

# %%
from tool_server.utils.utils import *
from datasets import load_dataset
blink_path = "/mnt/petrelfs/songmingyang/songmingyang/data/vl_reasoning/tool_dataset/BLINK"
blink_dataset = load_dataset(blink_path,"Jigsaw")
blink_dataset["test"][0]
'''
{'idx': 'test_Jigsaw_1',
 'question': 'Which image is the missing part in the first image?',
 'sub_task': 'Jigsaw',
 'image_1': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x232>,
 'image_2': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x116>,
 'image_3': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x116>,
 'image_4': None,
 'choices': ['the second image', 'the third image'],
 'answer': 'hidden',
 'prompt': 'Given the first image with the lower right corner missing, can you tell which one of the second image or the third image is the missing part? Imagine which image would be more appropriate to place in the missing spot. You can also carefully observe and compare the edges of the images.\nSelect from the following choices.\n\n(A) the second image\n(B) the third image\n',
 'explanation': ''}
'''
# Out:
# {'idx': 'test_Jigsaw_1',
#  'question': 'Which image is the missing part in the first image?',
#  'sub_task': 'Jigsaw',
#  'image_1': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x232>,
#  'image_2': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x116>,
#  'image_3': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x116>,
#  'image_4': None,
#  'choices': ['the second image', 'the third image'],
#  'answer': 'hidden',
#  'prompt': 'Given the first image with the lower right corner missing, can you tell which one of the second image or the third image is the missing part? Imagine which image would be more appropriate to place in the missing spot. You can also carefully observe and compare the edges of the images.\nSelect from the following choices.\n\n(A) the second image\n(B) the third image\n',
#  'explanation': ''}

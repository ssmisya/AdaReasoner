# %%
from tool_server.utils.utils import *
from tool_server.utils.prompts import tool_planning_model_prompt_one_tool_call
from tqdm import tqdm
import json, os
from tool_server.tool_workers.tool_manager.base_manager import ToolManager
from PIL import Image

setup_proxy()

# %%
manager = ToolManager("http://sh-idc1-10-140-37-6:30001")
# Out:
# 2025-07-10 16:44:16 | INFO | tool_manager | Offline Tools: ['crop_de', 'drawline_de']
# 2025-07-10 16:44:16 | INFO | tool_manager | controller_addr exsits, controller_url_location is http://sh-idc1-10-140-37-6:30001
# 2025-07-10 16:44:18 | INFO | tool_manager | Online Tools: ['DrawLine', 'Crop', 'HighlightBox', 'MaskBox', 'DrawShape', 'Point', 'GetBarInfo', 'GetSubplotInfo', 'GroundingDINO', 'OCR', 'SegmentRegionAroundPoint']
# 2025-07-10 16:44:18 | INFO | tool_manager | Not all tools is prepared successfully, missing tool ['LanguageModel']
# 2025-07-10 16:44:18 | INFO | tool_manager | ToolManager is initialized.
# 2025-07-10 16:44:18 | INFO | stdout | available_tools ['DrawLine', 'Crop', 'HighlightBox', 'MaskBox', 'DrawShape', 'Point', 'GetBarInfo', 'GetSubplotInfo', 'GroundingDINO', 'OCR', 'SegmentRegionAroundPoint']

# %%
manager.available_online_tools
# Out:
# ['DrawLine',
#  'Crop',
#  'HighlightBox',
#  'MaskBox',
#  'DrawShape',
#  'Point',
#  'GetBarInfo',
#  'GetSubplotInfo',
#  'GroundingDINO',
#  'OCR',
#  'SegmentRegionAroundPoint']

# %%
image = "/mnt/petrelfs/songmingyang/code/reasoning/tool-agent/tool_server/tool_workers/online_workers/test_cases/worker_tests/input_cases/bars2.jpg"
image = Image.open(image).convert("RGB")
image_base64 = pil_to_base64(image)
api_params = {
    "image":image_base64
}
api_name = "GetBarInfo"

# %%
tool_result = manager.call_tool(api_name, api_params)

# %%
tool_result
# Out:
# {'tool_response_from': 'GetBarInfo',
#  'status': 'success',
#  'message': 'Successfully extracted bar information',
#  'bars': {'R50-ImageNet': [96, 320, 278, 345],
#   'SimCLR-ft': [306, 320, 488, 345],
#   'VIVI': [496, 320, 658, 345],
#   'EfficientNet-B5': [666, 320, 828, 345],
#   'BiT-R101x3': [836, 320, 1000, 345]},
#  'error_code': 0,
#  'tool_reward': 4.0}
